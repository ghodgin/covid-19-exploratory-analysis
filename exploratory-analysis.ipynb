# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
covid_usa_df = pd.read_csv('data/usa_county_wise.csv')
covid_country_latest_df = pd.read_csv('data/country_wise_latest.csv')
covid_world_df = pd.read_csv('data/worldometer_data.csv')

covid_usa_df.sample(3)
# Out:
#              UID iso2 iso3  code3     FIPS   Admin2 Province_State  \
# 121685  84027099   US  USA    840  27099.0    Mower      Minnesota
# 126734  84055051   US  USA    840  55051.0     Iron      Wisconsin
# 11009   84020039   US  USA    840  20039.0  Decatur         Kansas
#
#        Country_Region        Lat       Long_          Combined_Key     Date  \
# 121685             US  43.671429  -92.752345  Mower, Minnesota, US  2/27/20
# 126734             US  46.263023  -90.242950   Iron, Wisconsin, US  2/28/20
# 11009              US  39.784684 -100.459408   Decatur, Kansas, US  1/25/20
#
#         Confirmed  Deaths
# 121685          0       0
# 126734          0       0
# 11009           0       0

# %% [markdown]
# Will potentially have to figure out / understand what 'FIPS' is or stands for.
# Also might try to filter the data where there is no confirmed / deaths

# %%
covid_country_latest_df.sample(5)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 120    Netherlands      53413    6160        189   47064        419
# 86         Jamaica        853      10        714     129         11
# 135       Portugal      50299    1719      35375   13205        135
# 69         Grenada         23       0         23       0          0
# 12         Bahrain      39482     141      36110    3231        351
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 120           1              0               11.53                   0.35
# 86            0              0                1.17                  83.70
# 135           2            158                3.42                  70.33
# 69            0              0                0.00                 100.00
# 12            1            421                0.36                  91.46
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# I like this datasset a bit more, but it is pretty broad. A lot more specific data perhaps! What countries have the highest confirmed amount?

# %%
confirmed_max = covid_country_latest_df.sort_values('Confirmed', ascending = False).head(20)

# %%
confirmed_barp = sns.barplot(x='Country/Region', y='Confirmed', data=covid_country_latest_df)
confirmed_barp.set_xticklabels(confirmed_barp.get_xticklabels(), rotation=90, size=8)
# Out:
# [Text(0, 0, 'Afghanistan'),
#  Text(1, 0, 'Albania'),
#  Text(2, 0, 'Algeria'),
#  Text(3, 0, 'Andorra'),
#  Text(4, 0, 'Angola'),
#  Text(5, 0, 'Antigua and Barbuda'),
#  Text(6, 0, 'Argentina'),
#  Text(7, 0, 'Armenia'),
#  Text(8, 0, 'Australia'),
#  Text(9, 0, 'Austria'),
#  Text(10, 0, 'Azerbaijan'),
#  Text(11, 0, 'Bahamas'),
#  Text(12, 0, 'Bahrain'),
#  Text(13, 0, 'Bangladesh'),
#  Text(14, 0, 'Barbados'),
#  Text(15, 0, 'Belarus'),
#  Text(16, 0, 'Belgium'),
#  Text(17, 0, 'Belize'),
#  Text(18, 0, 'Benin'),
#  Text(19, 0, 'Bhutan'),
#  Text(20, 0, 'Bolivia'),
#  Text(21, 0, 'Bosnia and Herzegovina'),
#  Text(22, 0, 'Botswana'),
#  Text(23, 0, 'Brazil'),
#  Text(24, 0, 'Brunei'),
#  Text(25, 0, 'Bulgaria'),
#  Text(26, 0, 'Burkina Faso'),
#  Text(27, 0, 'Burma'),
#  Text(28, 0, 'Burundi'),
#  Text(29, 0, 'Cabo Verde'),
#  Text(30, 0, 'Cambodia'),
#  Text(31, 0, 'Cameroon'),
#  Text(32, 0, 'Canada'),
#  Text(33, 0, 'Central African Republic'),
#  Text(34, 0, 'Chad'),
# ...

# %% [markdown]
# Yikes. Forgot to use the "confirmed_max" df

# %%
confirmed_barp = sns.barplot(x='Country/Region', y='Confirmed', data=confirmed_max)
confirmed_barp.set_xticklabels(confirmed_barp.get_xticklabels(), rotation=90, size=8)
# Out:
# [Text(0, 0, 'US'),
#  Text(1, 0, 'Brazil'),
#  Text(2, 0, 'India'),
#  Text(3, 0, 'Russia'),
#  Text(4, 0, 'South Africa'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Peru'),
#  Text(7, 0, 'Chile'),
#  Text(8, 0, 'United Kingdom'),
#  Text(9, 0, 'Iran'),
#  Text(10, 0, 'Pakistan'),
#  Text(11, 0, 'Spain'),
#  Text(12, 0, 'Saudi Arabia'),
#  Text(13, 0, 'Colombia'),
#  Text(14, 0, 'Italy'),
#  Text(15, 0, 'Turkey'),
#  Text(16, 0, 'Bangladesh'),
#  Text(17, 0, 'France'),
#  Text(18, 0, 'Germany'),
#  Text(19, 0, 'Argentina')]

# %%
covid_usa_df.head(1)
# Out:
#    UID iso2 iso3  code3  FIPS Admin2  Province_State Country_Region     Lat  \
# 0   16   AS  ASM     16  60.0    NaN  American Samoa             US -14.271
#
#      Long_        Combined_Key     Date  Confirmed  Deaths
# 0 -170.132  American Samoa, US  1/22/20          0       0
